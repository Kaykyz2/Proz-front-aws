# %%
# for planta in range(6):
#     print("Planta " + str(planta) + " regada.")

planta = 0

while planta < 6:
    print("Planta " + str(planta) + " regada.")
    planta += 1
# Out:
# Planta 0 regada.
# Planta 1 regada.
# Planta 2 regada.
# Planta 3 regada.
# Planta 4 regada.
# Planta 5 regada.
