# %%
# bebidaFavorita = "Sprite"
# preco = 2
# bebidaAlcoolica = False

# print(type(bebidaFavorita))
# print(type(preco))
# print(type(bebidaAlcoolica))

# print("Minha bebida favorita é: " + bebidaFavorita)
# print("O preço dela é: $" + str(preco) + " reais")

# if bebidaAlcoolica:
#     print("Ela é alcoólica")
# else:
#     print("Ela não é alcoólica")

#operador lógico exemplos
bebidaFavorita = "Sprite"
preco_1 = 2
almoçoHoje = "pão de queijo"
preco_2 = 4
orcamento = 4
precoTotal = preco_1 + preco_2
sobraGanho = orcamento - precoTotal

#print(precoTotal)

if orcamento >=  precoTotal:
      print("Vai dar pra comprar e ainda sobra:  $" + str(sobraGanho))
else:
      print("Vai dar pra comprar não, vai passar fome, falta: $" + str(sobraGanho))
# Out:
# Vai dar pra comprar não, vai passar fome, falta: $-2
