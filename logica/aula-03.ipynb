# %%
entradaNumeroDeEntrevistados = input("Insira o número de entrevistados: ")
numeroDeEntrevistados = int(entradaNumeroDeEntrevistados)

i = 1
while i <= numeroDeEntrevistados:
    print("Entrevistado n°: ",i)
    i = i + 1
# Out:
# Insira o número de entrevistados: 10
# Entrevistado n°:  1
# Entrevistado n°:  2
# Entrevistado n°:  3
# Entrevistado n°:  4
# Entrevistado n°:  5
# Entrevistado n°:  6
# Entrevistado n°:  7
# Entrevistado n°:  8
# Entrevistado n°:  9
# Entrevistado n°:  10
